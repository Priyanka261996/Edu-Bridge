# %% [markdown]
# # EDA and Visualisation

# %% [markdown]
# # Heart Failure clinical records

# %%
Heart failure occurs when the heart is not able to pump enough blood to the body.HF are only a subgroup of all the 
cardiovascular diseases that comprehend also coronary heart diseases (heart attacks), cerebrovascular diseases (strokes) 
and other pathologies that altogether kill every year approximately 17 million people around the world.In this notebook 
the analisys will be done starting from an EDA to understand the dataset and then applying some data visualisation technoques.

# %% [markdown]
# # Importing the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Reading the data set

# %%
d=pd.read_csv(r"C:\Users\bb\Desktop\data   data\heart_failure_clinical_records_dataset.csv")

# %%
d
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %% [markdown]
# # Print top 5 rows of data

# %%
d.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %% [markdown]
# # Print bottom 5 rows of data

# %%
d.tail()
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 294                    1   155000.0               1.1           143    1
# 295                    0   270000.0               1.2           139    0
# 296                    0   742000.0               0.8           138    0
# 297                    0   140000.0               1.4           140    1
# 298                    0   395000.0               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 294        1   270            0
# ...

# %% [markdown]
# # To check the no. of rows and columns

# %%
 d.shape
# Out:
# (299, 13)

# %% [markdown]
# # To check data types

# %%
d.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %% [markdown]
# # To check dimensions

# %%
d.ndim
# Out:
# 2

# %% [markdown]
# # Checking Index

# %%
d.index
# Out:
# RangeIndex(start=0, stop=299, step=1)

# %% [markdown]
# # To check size of data

# %%
d.size
# Out:
# 3887

# %% [markdown]
# # To check empty values

# %%
d.empty
# Out:
# False

# %% [markdown]
# # To check columns

# %%
d.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %% [markdown]
# # To check information about data

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.4 KB

# %% [markdown]
# # To check summary statistics

# %%
d.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
d.describe(include='all')
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %% [markdown]
# # To check null values if any

# %%
d.isna()
# Out:
#        age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    False    False                     False     False              False
# 1    False    False                     False     False              False
# 2    False    False                     False     False              False
# 3    False    False                     False     False              False
# 4    False    False                     False     False              False
# ..     ...      ...                       ...       ...                ...
# 294  False    False                     False     False              False
# 295  False    False                     False     False              False
# 296  False    False                     False     False              False
# 297  False    False                     False     False              False
# 298  False    False                     False     False              False
#
# ...

# %% [markdown]
# # To check sum of null values

# %%
d.isna().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %% [markdown]
# # To check unique values in the data

# %%
d.nunique()
# Out:
# age                          47
# anaemia                       2
# creatinine_phosphokinase    208
# diabetes                      2
# ejection_fraction            17
# high_blood_pressure           2
# platelets                   176
# serum_creatinine             40
# serum_sodium                 27
# sex                           2
# smoking                       2
# time                        148
# DEATH_EVENT                   2
# dtype: int64

# %% [markdown]
# # To check  correlation of data

# %%
d.corr()
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.088006                 -0.081584
# anaemia                   0.088006  1.000000                 -0.190741
# creatinine_phosphokinase -0.081584 -0.190741                  1.000000
# diabetes                 -0.101012 -0.012729                 -0.009639
# ejection_fraction         0.060098  0.031557                 -0.044080
# high_blood_pressure       0.093289  0.038182                 -0.070590
# platelets                -0.052354 -0.043786                  0.024463
# serum_creatinine          0.159187  0.052174                 -0.016408
# serum_sodium             -0.045966  0.041882                  0.059550
# sex                       0.065430 -0.094769                  0.079791
# smoking                   0.018668 -0.107290                  0.002421
# time                     -0.224068 -0.141414                 -0.009346
# ...

# %%
#Find :  that death event is positively correlated with serum_creatinine  and negatively correlated with diabetes .
#i.e. when serum_creatinine increase there is high chance of death and death due to heart failure is little affected by diabetes.

# %% [markdown]
# # Changing the datatypes

# %%
print(d["sex"].value_counts())
# 1 - Male , 0 - Female
# changing sex dtype to string
copy = d.copy()
Male = copy['sex'] == 1
copy.loc[Male,'sex'] = "Male"
Female = copy['sex'] == 0
copy.loc[Female,'sex'] = "Female"
copy.head()
# Out:
# 1    194
# 0    103
# Name: sex, dtype: int64
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium     sex  \
# 0                    1  265000.00               1.9           130    Male
# 1                    0  263358.03               1.1           136    Male
# 2                    0  162000.00               1.3           129    Male
# 3                    0  210000.00               1.9           137    Male
# 4                    0  327000.00               2.7           116  Female
#
#    smoking  time  DEATH_EVENT
# ...

# %% [markdown]
# # To check counts

# %%
sex_count = copy[['sex','DEATH_EVENT']].value_counts()
sex_count.head()
sex_count = sex_count.reset_index()
sex_count.columns  = ['sex','Death_event','count']
sex_count
# Out:
#       sex  Death_event  count
# 0    Male            0    132
# 1  Female            0     70
# 2    Male            1     62
# 3  Female            1     33

# %% [markdown]
# # Plotting the Scatter plot of age vs death event

# %%
sns.scatterplot(x='age',y='DEATH_EVENT',data=d)
plt.show()

# %% [markdown]
# # To create Heatmap for  checking correlation of the whole dataset

# %%
sns.heatmap(d.corr())
plt.show()

# %%
sns.heatmap(d.corr(),cmap='RdBu',linewidth=1,linecolor='yellow')
plt.show()

# %% [markdown]
# # To create subplot

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(d.corr(method='pearson'),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # To create Boxplot for checking the outliers

# %%
sns.boxplot(x =d.creatinine_phosphokinase, color = 'teal')
plt.show()

# %%
# Find : many outliers in the creatinine_phosphokinase.

# %%
sns.boxplot(x = d.ejection_fraction, color = 'teal')
plt.show()

# %%
# Find : only two outliers, can remove easily as :-

# %%
d[d['ejection_fraction']>=70]
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 64   45.0        0                       582         0                 80
# 217  54.0        1                       427         0                 70
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 64                     0  263358.03              1.18           137    0
# 217                    1  151000.00              9.00           137    0
#
#      smoking  time  DEATH_EVENT
# 64         0    63            0
# 217        0   196            1

# %%
sns.boxplot(x=d.time, color = 'teal')
plt.show()

# %%
# Find : No outliers in time .

# %%
sns.boxplot(x=d.serum_creatinine, color = 'teal')
plt.show()

# %%
# Find : Many outliers in serum_creatinine.

# %% [markdown]
# # To create Boxplot for checking the majority of ages

# %%
print(sns.boxplot(x = d["age"]))
plt.title("Range of age in the dataset")
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, 'Range of age in the dataset')

# %%
# Find : majority of ages in the data are inbetween 50-70.

# %% [markdown]
# # Plotting kdeplot

# %%
print(sns.kdeplot(data = d["anaemia"],shade = True))
sns.barplot(x = d["anaemia"],y =d["DEATH_EVENT"],saturation  = 0.1)
plt.title("Anaemia VS Death_event")
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, 'Anaemia VS Death_event')

# %%
#Find :  a decent amount of people does not have a lower quantity of blood cells.
# as expected, there are more deaths from stroke who have anaemia.

# %%
print(sns.kdeplot(data = d["high_blood_pressure"],shade = True))
sns.barplot(x = d["high_blood_pressure"],y =d["DEATH_EVENT"],saturation  = 0.1)
plt.title("High Blood Pressure VS Death_event")
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, 'High Blood Pressure VS Death_event')

# %%
sns.kdeplot(data=d, x="creatinine_phosphokinase", hue="DEATH_EVENT",fill=True, common_norm=False,
            palette="crest",alpha=.5, linewidth=0,)
# Out:
# <AxesSubplot:xlabel='creatinine_phosphokinase', ylabel='Density'>

# %%
sns.kdeplot(
   data=d, x="platelets", hue="DEATH_EVENT",
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0,
)
# Out:
# <AxesSubplot:xlabel='platelets', ylabel='Density'>

# %%
sns.kdeplot(
   data=d, x="serum_creatinine", hue="DEATH_EVENT",
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0,
)
# Out:
# <AxesSubplot:xlabel='serum_creatinine', ylabel='Density'>

# %%
sns.kdeplot(
   data=d, x="serum_sodium", hue="DEATH_EVENT",
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0,
)
# Out:
# <AxesSubplot:xlabel='serum_sodium', ylabel='Density'>

# %%
sns.kdeplot(
   data=d, x="time", hue="DEATH_EVENT",
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0,
)
# Out:
# <AxesSubplot:xlabel='time', ylabel='Density'>

# %% [markdown]
# # Plot the distplot for death and age event

# %%
sns.distplot(x=d['DEATH_EVENT'])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(x=d['age'])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Find : that age data is nearly negatively skewed.

# %% [markdown]
# # Plotting the Bar graph

# %%
age_yes = d[d['DEATH_EVENT'] == 1].age
age = d.age

plt.figure(figsize=(8,6))
plt.xlabel('Age')
plt.ylabel('Death Event')
plt.hist([age_yes, age], label=['Death Event', 'Total per age'])
plt.legend()

# %%
# Find : No. of death at age 60 are higher.

# %%
sns.barplot(x = 'DEATH_EVENT' , y = 'age' , data = d)
plt.title("Age VS Death_event")
# Out:
# Text(0.5, 1.0, 'Age VS Death_event')

# %%
#Find : the average age does not play any vital role in Heart Failure.

# %% [markdown]
# # Plot the catplot

# %%
sns.catplot(x='diabetes', y="age", hue = 'DEATH_EVENT', kind="box", data=d)

# %%
sns.catplot(x='high_blood_pressure', y="serum_sodium",hue = 'DEATH_EVENT', kind="box", data=d)

# %% [markdown]
# # Plot the line plot

# %%
sns.lineplot(data= d, x='creatinine_phosphokinase',y='platelets', color='goldenrod')
# Out:
# <AxesSubplot:xlabel='creatinine_phosphokinase', ylabel='platelets'>

# %% [markdown]
# # Plot the strip plot

# %%
sns.stripplot(x = d["DEATH_EVENT"],y = d["creatinine_phosphokinase"])
# higher creatinine_phosphokinase means a high level of stress. but it does not leave any major impact on heart failure
plt.title("Creatinine Phosphokinase VS Death_event")
# Out:
# Text(0.5, 1.0, 'Creatinine Phosphokinase VS Death_event')

# %% [markdown]
# # Plot the swarm plot

# %%
sns.swarmplot(x = d["DEATH_EVENT"], y = d["ejection_fraction"],hue = d["DEATH_EVENT"],s = 4)
# when the ejection fraction falls below 30 death event increases
plt.title("Ejection fraction VS Death_event")
# Out:
# Text(0.5, 1.0, 'Ejection fraction VS Death_event')

# %% [markdown]
# # Plot the subplots

# %%
plt.figure(figsize = (16,6))
plt.subplot(1,2,1)
sns.kdeplot(x = d["platelets"])
plt.subplot(1,2,2)
sns.scatterplot(x = d["DEATH_EVENT"],y = d["platelets"] ,hue = d["DEATH_EVENT"])
# majority of entries have normal number of platelets (between 150,000 - 400,000) and 
# entries with platelets < 200,000 have greater risk of heart failure.
plt.title("Platelets VS Death_event")
# Out:
# Text(0.5, 1.0, 'Platelets VS Death_event')

# %%
plt.figure(figsize = (16,6))
plt.subplot(1,2,1)
sns.kdeplot(x = d["serum_creatinine"])
# average values of serum creatinine is <= 1 for normal behaviour of body
plt.subplot(122)
sns.scatterplot(x = d["DEATH_EVENT"],y = d["serum_creatinine"],hue =d["DEATH_EVENT"])
# increased values of serum creatinine leads to heart failure
plt.title("Serum Creatinine VS Death_event")
# Out:
# Text(0.5, 1.0, 'Serum Creatinine VS Death_event')

# %% [markdown]
# # Plot the data according to numerical and categoical features

# %%
numerical_features = ["age", "creatinine_phosphokinase", "ejection_fraction", "platelets", "serum_creatinine", "serum_sodium"]
categorical_features = ["anaemia", "diabetes", "high_blood_pressure", "sex", "smoking"]

# %%
plt.figure(figsize=(18, 27))

for i, col in enumerate(numerical_features):
    plt.subplot(6, 4, i*2+1)
    plt.subplots_adjust(hspace =.25, wspace=.3)
    
    plt.grid(True)
    plt.title(col)
    sns.kdeplot(d.loc[d["DEATH_EVENT"]==0, col], label="alive", color = "#990303", shade=True, kernel='gau', cut=0)
    sns.kdeplot(d.loc[d["DEATH_EVENT"]==1, col], label="dead",  color = "#292323", shade=True, kernel='gau', cut=0)
    plt.subplot(6, 4, i*2+2) 
    sns.boxplot(y = col, data = d, x="DEATH_EVENT", palette = ["#990303", "#9C9999"])

# %%
plt.figure(figsize=(12, 8))

for i, col in enumerate(categorical_features):
    plt.subplot(2, 3, i+1)
    plt.title(col)
    plt.subplots_adjust(hspace =.5, wspace=.3)
    sns.countplot(data=d, x=col, hue="DEATH_EVENT", palette = ["#990303", "#9C9999"], alpha=0.8, edgecolor="k", linewidth=1)

# %% [markdown]
# # Plot the pairplots

# %%
sns.pairplot(d)
plt.show()

# %%
sns.pairplot(d,diag_kind='kde',kind='reg')
plt.show()

# %% [markdown]
# # Conclusion : First of all there are many outliers in the data except  in 'time' . Death event is positively correlated with serum_creatinine  and negatively correlated with diabetes .when serum_creatinine increase there is high chance of death and death due to heart failure is little affected by diabetes.Majority of death is at age 60 and due to ammonia.Average age doesnot play any vital role in heart failure.
